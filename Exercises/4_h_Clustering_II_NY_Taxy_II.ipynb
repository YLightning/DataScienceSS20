# %% [markdown]
# # Exercise: Geographical Cluster Analysis of Taxi Rides
# Using the NY Taxi data set (see Use Case Block I) and the use case from the lecture...

# %%
import pandas as pd
import numpy as np
import folium
from sklearn.metrics.pairwise import euclidean_distances

# %%
#check if notebook runs in colab
import sys
IN_COLAB = 'google.colab' in sys.modules
print('running in Colab:',IN_COLAB)
path='..'
if IN_COLAB:
  #in colab, we need to clone the data from the repo
  # !git clone https://github.com/keuperj/DataScienceSS20.git
  path='DataScienceSS20'
# Out:
# running in Colab: False

# %%
# we load the data we have saved after wrangling and pre-processing in block I
train=pd.read_csv(path+'/DATA/train_cleaned.csv')

# %%
#select only the culumns with the ride coordinates
coordinates = train[ ['pickup_latitude','pickup_longitude','dropoff_latitude' , 'dropoff_longitude' ] ]
coordinates.shape
# Out:
# (400000, 4)

# %% [markdown]
# ## Clustering approach from the lecture
# we will be using simple K-Means:
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html

# %%
from sklearn.cluster import KMeans

# %%
#define number of clusters and create instance
clusters=100
myKMeans=KMeans(n_clusters=clusters, n_jobs=-1)#parallelize to all cores

# %%
#train model
myKMeans.fit(coordinates.to_numpy()[:100000,:])#use only subset of the data to make it faster
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=100, n_init=10, n_jobs=-1, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
#get cluster centers
centers=myKMeans.cluster_centers_

# %%
len(coordinates)
# Out:
# 400000

# %%
#draw map: green: start, red: end
cluster_map = folium.Map(location = [40.730610,-73.935242],zoom_start = 12,)
for i in range(clusters):
    folium.CircleMarker([centers[i,0], centers[i,1]], radius=3,                
                        color="green", 
                        fill_opacity=0.9
                       ).add_to(cluster_map)
    folium.CircleMarker([centers[i,2], centers[i,3]], radius=3,                
                        color="red", 
                        fill_opacity=0.9
                       ).add_to(cluster_map)
    folium.PolyLine([ [centers[i,0],centers[i,1]] , [centers[i,2],centers[i,3]]  ], color="black", weight=2.5, opacity=1).add_to(cluster_map)

# %%
cluster_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Exercise 1
# Write a function ```show_cluster(cluster_number,...)``` that draws the cluster centers and all start and end points of a given cluster in the map.
# * use the ```predict()``` method to map all data in ```train_data``` to a cluster center
# * use ```folium.CircleMarker``` to draw all members of a given cluster

# %%
def show_cluster(cluster_number, myKMeans, coordinates):
    myKMeans = myKMeans
    coordinates = coordinates
    cluster_number = cluster_number
    pred_cluster = myKMeans.predict(coordinates)
    mask = (cluster_number == pred_cluster)
    print(mask)
    cluster_Data = coordinates[mask]
    Newcluster_map = folium.Map(location = [40.730610,-73.935242],zoom_start = 12,)
    for i in range(0,4,2):
        for j in range(len(cluster_Data)):
            if cluster_Data[j,i]!=False:
                folium.CircleMarker([cluster_Data[j,i], cluster_Data[j,i+1]], radius=3,                
                        color="black", 
                        fill_opacity=0.9
                        ).add_to(Newcluster_map)
    return Newcluster_map

# %%
show_cluster(80, myKMeans, coordinates.to_numpy()[:100000,:])
# Out:
# [False False False ... False False False]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Exercise 2
# Write a function ```cluster_var(cluster_number,...)``` that computes the intra- and extra cluster variance for a given cluster. Apply it to all clusters and compare the results for k=100 and k=10.

# %%
    ShorterCoordi = coordinates.to_numpy()[:100000,:]
    pred_cluster = myKMeans.predict(coordinates.to_numpy()[:100000,:])
    mask = (50 == pred_cluster)
    distanc_pred_Cluster
    print(mask)
    cluster_Data = ShorterCoordi[mask]
    cluster_Data
    for i in range(0,4,2):
        for j in range(len(cluster_Data)):
            euclidean_distances(, X)
# Out:
# [False False False ... False False False]
# array([[ 40.773883  , -73.873027  ,  40.769545  , -73.984545  ],
#        [ 40.774105  , -73.872862  ,  40.764393  , -73.970593  ],
#        [ 40.768622  , -73.863072  ,  40.736167  , -73.982145  ],
#        ...,
#        [ 40.77008057, -73.86307526,  40.73031998, -73.95366669],
#        [ 40.771083  , -73.865937  ,  40.763762  , -73.985805  ],
#        [ 40.721359  , -73.844459  ,  40.739371  , -73.989984  ]])

# %%
def cluster_var(cluster_number, ):
    for i in range...:
        for j in range...:
        euclidean_distances(X, X)
clusters=100
myKMeans=KMeans(n_clusters=clusters, n_jobs=-1)#parallelize to all cores-
